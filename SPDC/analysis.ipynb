# %%
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.8 MB 8.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.8 MB 8.7 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.8 MB 8.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.8 MB 8.2 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.8 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 8.7 MB/s  0:00:01
# ...
