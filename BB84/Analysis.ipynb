# %%
import pandas as pd
import numpy as np
dfalice={}
dfbob={}

# %%
for i in range(33):
    with open(rf"BB84 data\Alice_{i+1}.csv", "r") as file:
        dfalice[i]=pd.read_csv(file,sep=';')
        file.close()
    with open(rf"BB84 data\Bob_{i+1}.csv", "r") as file:
        dfbob[i]=pd.read_csv(file,sep=';')
        file.close()

# %%
dfalice[0]
# Out:
#     ROW BASIS  BITVALUE DET?
# 0     1     +         0    Y
# 1     2     +         0    Y
# 2    12     +         1    Y
# 3    15     X         1    Y
# 4    17     X         1    Y
# 5    19     X         1    Y
# 6    25     +         1    Y
# 7    26     +         0    Y
# 8    31     X         0    Y
# 9    37     +         0    Y
# 10   41     X         0    Y
# 11   47     +         1    Y
# 12   50     X         1    Y
# 13   58     +         0    Y
# 14   60     X         1    Y
# 15   61     +         1    Y
# 16   65     X         1    Y
# 17   71     X         0    Y
# 18   73     X         1    Y
# 19   78     X         1    Y
# 20   83     +         1    Y
# 21   84     X         1    Y
# 22   86     +         1    Y
# 23   90     +         0    Y
# 24   98     +         0    Y
